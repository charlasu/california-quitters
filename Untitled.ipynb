# %%
#import dependencies
import pymongo
import json

#connect local client to remote server through uri
connect = 'mongodb://davinci:monalisa7@ds253891.mlab.com:53891/project_2'
client = pymongo.MongoClient(connect)

#create reference to project_2 db
db = client.project_2

# %%
collection = db.Rent_Value_Data
rent_data = []

# %%
cursor = collection.find({})
for doc in cursor:
    appendable_dict = {
        'date': doc['Date'],
        'us_rent': doc['US_Rent'],
        'us_val': doc['US_Value'],
        'ca_rent': doc['California_Rent'],
        'ca_val': doc['California_Value'],
        'az_rent': doc['Arizona_Rent'],
        'az_val': doc['Arizona_Value'],
        'co_rent': doc['Colorado_Rent'],
        'co_val': doc['Colorado_Value'],
        'id_rent': doc['Idaho_Rent'],
        'id_val': doc['Idaho_Value'],
        'nm_rent': doc['New_Mexico_Rent'],
        'nm_val': doc['New_Mexico_Value'],
        'nv_rent': doc['Nevada_Rent'],
        'nv_val': doc['Nevada_Value'],
        'or_rent': doc['Oregon_Rent'],
        'or_val': doc['Oregon_Value'],
        'ut_rent': doc['Utah_Rent'],
        'ut_val': doc['Utah_Value'],
        'wa_rent': doc['Washington_Rent'],
        'wa_val': doc['Washington_Value']
    }
    pop_data.append(appendable_dict)
return json.dumps(pop_data)
# Out:
# [{"moved_to": "Arizona", "year": 2010, "num_outbound": 47164, "pop": 6407002}, {"moved_to": "Colorado", "year": 2010, "num_outbound": 26089, "pop": 5048029}, {"moved_to": "Idaho", "year": 2010, "num_outbound": 8932, "pop": 1570912}, {"moved_to": "Nevada", "year": 2010, "num_outbound": 35472, "pop": 2702797}, {"moved_to": "New Mexico", "year": 2010, "num_outbound": 6547, "pop": 2064607}, {"moved_to": "Oregon", "year": 2010, "num_outbound": 34190, "pop": 3837073}, {"moved_to": "Utah", "year": 2010, "num_outbound": 12187, "pop": 2775260}, {"moved_to": "Washington", "year": 2010, "num_outbound": 39468, "pop": 6741386}, {"moved_to": "Arizona", "year": 2011, "num_outbound": 49635, "pop": 6465488}, {"moved_to": "Colorado", "year": 2011, "num_outbound": 23234, "pop": 5116411}, {"moved_to": "Idaho", "year": 2011, "num_outbound": 9021, "pop": 1583180}, {"moved_to": "Nevada", "year": 2011, "num_outbound": 40114, "pop": 2718170}, {"moved_to": "New Mexico", "year": 2011, "num_outbound": 7066, "pop": 2077744}, {"moved_to": "Oregon", "year": 2011, "num_outbound": 34214, "pop": 3865845}, {"moved_to": "Utah", "year": 2011, "num_outbound": 18237, "pop": 2815430}, {"moved_to": "Washington", "year": 2011, "num_outbound": 38421, "pop": 6819155}, {"moved_to": "Arizona", "year": 2012, "num_outbound": 44889, "pop": 6544211}, {"moved_to": "Colorado", "year": 2012, "num_outbound": 22152, "pop": 5186330}, {"moved_to": "Idaho", "year": 2012, "num_outbound": 10280, "pop": 1594673}, {"moved_to": "Nevada", "year": 2012, "num_outbound": 49978, "pop": 2752410}, {"moved_to": "New Mexico", "year": 2012, "num_outbound": 4536, "pop": 2083590}, {"moved_to": "Oregon", "year": 2012, "num_outbound": 31862, "pop": 3893920}, {"moved_to": "Utah", "year": 2012, "num_outbound": 15286, "pop": 2854222}, {"moved_to": "Washington", "year": 2012, "num_outbound": 45597, "pop": 6890899}, {"moved_to": "Arizona", "year": 2013, "num_outbound": 47959, "pop": 6616124}, {"moved_to": "Colorado", "year": 2013, "num_outbound": 23714, "pop": 5262556}, {"moved_to": "Idaho", "year": 2013, "num_outbound": 9232, "pop": 1610187}, {"moved_to": "Nevada", "year": 2013, "num_outbound": 47897, "pop": 2786547}, {"moved_to": "New Mexico", "year": 2013, "num_outbound": 5697, "pop": 2085161}, {"moved_to": "Oregon", "year": 2013, "num_outbound": 31380, "pop": 3919664}, {"moved_to": "Utah", "year": 2013, "num_outbound": 15794, "pop": 2899961}, {"moved_to": "Washington", "year": 2013, "num_outbound": 37150, "pop": 6963410}, {"moved_to": "Arizona", "year": 2014, "num_outbound": 57446, "pop": 6706435}, {"moved_to": "Colorado", "year": 2014, "num_outbound": 24506, "pop": 5342311}, {"moved_to": "Idaho", "year": 2014, "num_outbound": 10057, "pop": 1630391}, {"moved_to": "Nevada", "year": 2014, "num_outbound": 48954, "pop": 2831730}, {"moved_to": "New Mexico", "year": 2014, "num_outbound": 4986, "pop": 2083207}, {"moved_to": "Oregon", "year": 2014, "num_outbound": 35334, "pop": 3960673}, {"moved_to": "Utah", "year": 2014, "num_outbound": 14510, "pop": 2938671}, {"moved_to": "Washington", "year": 2014, "num_outbound": 40085, "pop": 7046931}, {"moved_to": "Arizona", "year": 2015, "num_outbound": 54646, "pop": 6802262}, {"moved_to": "Colorado", "year": 2015, "num_outbound": 29029, "pop": 5440445}, {"moved_to": "Idaho", "year": 2015, "num_outbound": 18928, "pop": 1649324}, {"moved_to": "Nevada", "year": 2015, "num_outbound": 54765, "pop": 2883057}, {"moved_to": "New Mexico", "year": 2015, "num_outbound": 6721, "pop": 2082264}, {"moved_to": "Oregon", "year": 2015, "num_outbound": 40447, "pop": 4016537}, {"moved_to": "Utah", "year": 2015, "num_outbound": 18154, "pop": 2984917}, {"moved_to": "Washington", "year": 2015, "num_outbound": 45609, "pop": 7152818}, {"moved_to": "Arizona", "year": 2016, "num_outbound": 64756, "pop": 6908642}, {"moved_to": "Colorado", "year": 2016, "num_outbound": 26909, "pop": 5530105}, {"moved_to": "Idaho", "year": 2016, "num_outbound": 17019, "pop": 1680026}, {"moved_to": "Nevada", "year":  ...

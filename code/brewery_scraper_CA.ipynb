# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/california/5/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                 Brewery             Location Est. Year
# 0             101 North Brewing Company             Petaluma      2012
# 1            14 Cannons Brewing Company     Westlake Village      2017
# 2                2 Kids Brewing Company            San Diego      2014
# 3                       2 Tread Brewing           Santa Rosa      2018
# 4        21st Amendment Brewery (Kirin)        San Francisco      2001
# 5                           3 Disciples           Sebastopol      2016
# 6                3 Iron Brewing Company               Colton      2015
# 7                      32 North Brewing            San Diego      2014
# 8              47 Hills Brewing Company  South San Francisco      2017
# 9                    8 Bit Brewing (CA)             Murrieta      2016
# 10                          800 Degrees          Sara Monica      2018
# 11                     927 Beer Company              Cambria      2012
# 12                Abnormal Beer Company            San Diego      2015
# 13           Absolution Brewing Company             Torrance      2014
# 14     Acoustic Ales Brewing Experiment            San Diego      2013
# 15                  Adobe Creek Brewing               Novato      2017
# 16           Aftershock Brewing Company             Temecula      2012
# 17       Alameda Island Brewing Company              Alameda      2015
# 18                  Alaro Craft Brewery           Sacramento      2018
# 19            Ale House Brewing Company             San Jose      2016
# 20                       Ale Industries              Oakland      2009
# 21             AleSmith Brewing Company            San Diego      1995
# 22                        Align Brewing            San Diego      2017
# 23               All-American Ale Works              Anaheim      2018
# 24                 Almanac Beer Company        San Francisco      2011
# 25               Alosta Brewing Company               Covina      2013
# 26               Alpenglow Beer Company            Lafayette      2016
# 27           Alpha Acid Brewing Company              Belmont      2014
# 28             Alpine Beer Company (CA)               Alpine      2002
# 29               Alpine Village Hofbrau             Torrance      2001
# ..                                  ...                  ...       ...
# 766              Uproar Brewing Company             San Jose      2017
# 767    Urban Roots Brewing & Smokehouse           Sacramento      2018
# 768                     Valiant Brewing               Orange      2013
# 769                    Venice Ale House               Venice      2013
# 770           Venice Beach Beer Company               Venice      2015
# 771                 Venice Duck Brewery          Los Angeles      2014
# 772       Ventura Coast Brewing Company              Ventura      2017
# 773                Verdugo West Brewing              Burbank      2017
# 774           Viewpoint Brewing Company              Del Mar      2017
# 775             W Brewing / 559 Brewing               Clovis      2013
# 776                    Waganupa Brewing              Chester      2016
# 777            Waterman Brewing Company            Elk Grove      2017
# 778          Wavelength Brewing Company                Vista      2014
# 779            Westlake Brewing Company     Westlake Village      2016
# 780                          White Labs            San Diego      2012
# 781                       Wicks Brewing            Riverside      2013
# 782               Wiens Brewing Company             Temecula      2012
# 783         Wild Barrel Brewing Company           San Marcos      2017
# 784            Wildcard Brewing Company             Redding       2013
# 785                     Wiretap Brewing          Los Angeles      2017
# 786          Wolf Creek Brewing Company             Valencia      1997
# 787            Woodfour Brewing Company           Sebastopol      2013
# 788                 Woods Bar & Brewery              Oakland      2014
# 789             Woody's Brewing Company              Redding      2015
# 790         Working Man Brewing Company            Livermore      2013
# 791   World Brews, Winery Exchange Inc.               Novato      2010
# 792                Yolo Brewing Company      West Sacramento      2014
# 793            Yorkshire Square Brewery             Torrance      2017
# 794                   Zona Rosa Brewing             Pasadena      2017
# 795                  Zymurgy Brew Works             Torrance      2017
#
# [796 rows x 3 columns]

# %%
data.to_csv("../brewery_data/breweries_CA.csv", index=False, header=True)

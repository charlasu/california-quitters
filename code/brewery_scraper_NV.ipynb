# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/nevada/28/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                               Brewery         Location  \
# 0                      10 Torr Distilling and Brewing             Reno
# 1                                  Able Baker Brewing        Las Vegas
# 2                                     Alibi Ale Works  Incline Village
# 3                                  Astronomy Aleworks        Henderson
# 4                                    Bad Beat Brewing        Henderson
# 5                              Banger Brewing Company        Las Vegas
# 6                         Barley's Casino and Brewing        Henderson
# 7                            Battle Born Beer Company             Reno
# 8                           Big Dog's Brewing Company        Las Vegas
# 9                             Boulder Dam Brewing Co.     Boulder City
# 10                          Branded Hearts Distillery             Reno
# 11                              Brasserie Saint James             Reno
# 12              Brew Brothers Reno (El Dorado Casino)             Reno
# 13                                  Bugsy Brewing Inc        Las Vegas
# 14                                  Camo Beer Company        Las Vegas
# 15                            Chicago Brewing Company        Las Vegas
# 16                                  CraftHaus Brewery        Henderson
# 17                      Ellis Island Casino & Brewery        Las Vegas
# 18                        Great Basin Brewing Company           Sparks
# 19                        High Sierra Brewing Company           Sparks
# 20                                   Hop Nuts Brewing        Las Vegas
# 21                                 IMBĪB Custom Brews             Reno
# 22                       Joseph James Brewing Company        Henderson
# 23                           Lead Dog Brewing Company             Reno
# 24                                   Lovelady Brewing       Henderson
# 25                                   No Limit Brewing        Las Vegas
# 26                                Pigeon Head Brewery             Reno
# 27   Pints Brewery & Sports Bar on the Colorado Belle         Laughlin
# 28                               PT's Brewing Company        Las Vegas
# 29                      Record Street Brewing Company             Reno
# 30                           Revision Brewing Company           Sparks
# 31                      Ruby Mountain Brewing Company    Clover Valley
# 32                          Shoe Tree Brewing Company      Carson City
# 33                   Silver Peak Restaurant & Brewery             Reno
# 34                              Sin City Beer Company        Las Vegas
# 35                                 Stoneyhead Brewery             Reno
# 36                               Tenaya Creek Brewery        Las Vegas
# 37                               The Brewer's Cabinet             Reno
# 38               The Depot Craft Brewery & Distillery             Reno
# 39                                          The Union      Carson City
# 40                            Tonopah Brewing Company          Tonopah
# 41            Triple 7 Brewpub at Main Street Station        Las Vegas
# 42                     Two Bald Guys Beverage Company             Reno
# 43                     Under The Rose Brewing Company             Reno
# 44                   Virginia City Brewery & Taphouse    Virginia City
#
#    Est. Year
# 0       2017
# 1       2016
# 2       2014
# 3       2018
# 4       2014
# 5       2012
# 6       2001
# 7       2013
# 8       2004
# 9       2007
# 10      2016
# 11      2012
# 12      2002
# 13      2012
# 14      2012
# 15      2000
# 16      2014
# 17      2000
# 18      1999
# 19      2011
# 20      2015
# 21      2015
# 22      2009
# 23      2017
# 24      2016
# 25      2012
# 26      2014
# 27      2002
# 28      2016
# 29      2016
# 30      2017
# 31      1994
# 32      2017
# 33      2003
# 34      2003
# 35      2013
# 36      1999
# 37      2012
# 38      2015
# 39      2018
# 40      2014
# 41      1997
# 42      2015
# 43      2013
# 44      2015

# %%
data.to_csv("../brewery_data/breweries_NV.csv", index=False, header=True)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/washington/47/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                                Brewery           Location  \
# 0                        101 Brewery & Twana Roadhouse           Quilcene
# 1                                  192 Brewing Company            Kenmore
# 2                               20 Corners Brewing Co.        Woodinville
# 3                                  210 Brewing Company          Arlington
# 4                                  238 Brewing Company        Green Bluff
# 5                             5 Rights Brewing Company       Lake Stevens
# 6                               54°40' Brewing Company          Washougal
# 7                                       7 Seas Brewing         Gig Harbor
# 8                              Airways Brewing Company               Kent
# 9                          Alpine Brewing Company (WA)           Oroville
# 10    American Brewing Company (Pacific Brewing & M...            Edmonds
# 11                             Ashtown Brewing Company           Longview
# 12                               Aslan Brewing Company         Bellingham
# 13                                    At Large Brewing            Everett
# 14                             Atomic Ale Brewpub (US)           Richland
# 15                                         Atwood Ales             Blaine
# 16                           Backwoods Brewing Company             Carson
# 17                                Bad Bulldogs Brewery          Bremerton
# 18                             Bad Jimmy's Brewing Co.            Seattle
# 19                     Badass Backyard Brewing Company           Millwood
# 20                     Badger Mountain Brewing Company          Wenatchee
# 21                   Bainbridge Island Brewing Company  Bainbridge Island
# 22                        Bale Breaker Brewing Company             Yakima
# 23                                      Barhop Brewing       Port Angeles
# 24                             Barrel Mountain Brewing      Battle Ground
# 25                                     Bastion Brewing          Anacortes
# 26                                     Bavaria Brewing          Sammamish
# 27                                  Beardslee Alehouse            Bothell
# 28                            Beerded Brothers Brewing          Vancouver
# 29                            Bellevue Brewing Company           Bellevue
# ..                                                 ...                ...
# 327                        Two Sisters Honey & Brewery        Benton City
# 328                       Urban Family Brewing Company            Seattle
# 329                             V Twin Brewing Company     Spokane Valley
# 330                            Valhöll Brewing Company            Poulsbo
# 331                       Valley House Brewing Company             Duvall
# 332                              Varietal Beer Company          Sunnyside
# 333                             Vashon Brewing Company             Vashon
# 334                              Vessel Wines and Ales        Woodinville
# 335                                  Victor 23 Brewing          Vancouver
# 336                          Waddell's Brewing Company            Spokane
# 337                                Walking Man Brewing          Stevenson
# 338                                     Wander Brewing         Bellingham
# 339                              Watts Brewing Company            Bothell
# 340                   Wenatchee Valley Brewing Company          Wenatchee
# 341                              West Highland Brewing          Vancouver
# 342                       West Seattle Brewing Company            Seattle
# 343                                Western Red Brewing            Poulsbo
# 344                           Westport Brewing Company           Westport
# 345                          Wet Coast Brewing Company         Gig Harbor
# 346                                    Whipsaw Brewing         Ellensburg
# 347                              Whiskey Ridge Brewing          Arlington
# 348                       Whistle Punk Brewing Company            Spokane
# 349                       White Bluffs Brewing Company           Richland
# 350                          Whitewall Brewing Company         Marysville
# 351                          Whitstran Brewing Company            Prosser
# 352                            Willapa Brewing Company            Raymond
# 353                                    Wingman Brewers             Tacoma
# 354                               Yakima Craft Brewing             Yakima
# 355                                 Young Buck Brewing            Spokane
# 356                             Zythum Brewing Company          Fairfield
#
#     Est. Year
# 0        2013
# 1        2010
# 2        2016
# 3        2015
# 4        2015
# 5        2015
# 6        2015
# 7        2009
# 8        2010
# 9        2000
# 10       2011
# 11       2013
# 12       2014
# 13       2015
# 14       2005
# 15       2016
# 16       2012
# 17       2018
# 18       2014
# 19       2015
# 20       2013
# 21       2012
# 22       2013
# 23       2011
# 24       2016
# 25       2016
# 26       2014
# 27       2015
# 28       2014
# 29       2011
# ..        ...
# 327      2011
# 328      2012
# 329      2017
# 330      2010
# 331      2017
# 332      2017
# 333      2011
# 334      2016
# 335      2016
# 336      2013
# 337      2003
# 338      2014
# 339      2015
# 340      2016
# 341      2011
# 342      2013
# 343      2018
# 344      2011
# 345      2015
# 346      2016
# 347      2014
# 348      2016
# 349      2011
# 350      2014
# 351      2003
# 352      2018
# 353      2011
# 354      2008
# 355      2016
# 356      2014
#
# [357 rows x 3 columns]

# %%
data.to_csv("../brewery_data/breweries_WA.csv", index=False, header=True)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/colorado/6/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                   Brewery           Location Est. Year
# 0                105 West Brewing Company        Castle Rock      2015
# 1                       12 Degree Brewing         Louisville      2013
# 2                    14er Brewing Company             Denver      2016
# 3               2 Rascals Brewing Company           Montrose      2013
# 4                        3 Freaks Brewery    Highlands Ranch      2014
# 5                        300 Suns Brewing           Longmont      2013
# 6                38 State Brewing Company          Littleton      2014
# 7                 4 Noses Brewing Company         Broomfield      2014
# 8                            4B's Brewery          Cedaredge      2015
# 9                           5280 NRG, LLC  Greenwood Village      2014
# 10              7 Hermits Brewing Company              Eagle      2014
# 11              Acidulous Brewing Company            Boulder      2016
# 12                     Alpine Dog Brewery             Denver      2014
# 13            Alternation Brewing Company             Denver      2017
# 14                        Amalgam Brewing              Niwot      2016
# 15               Amicas Pizza & Microbrew             Salida      2003
# 16                    Angry James Brewery       Silverthorne      2018
# 17                 Animas Brewing Company            Durango      2014
# 18                  Asher Brewing Company            Boulder      2009
# 19                  Aspen Brewing Company              Aspen      2008
# 20                   Atom Brewing Company               Erie      2016
# 21                  Atrevida Beer Company   Colorado Springs      2018
# 22             Avalanche  Brewing Company          Silverton      2014
# 23                  Avery Brewing Company            Boulder      1993
# 24               Backcountry Brewery (CO)             Frisco      2000
# 25                  Baere Brewing Company             Denver      2014
# 26             Banded Oak Brewing Company             Denver      2016
# 27          Barnett & Son Brewing Company             Parker      2016
# 28            Barrels and Bottles Brewery             Golden      2013
# 29                 Beer By Design Brewery         Northglenn      2013
# ..                                    ...                ...       ...
# 333                     Uhl's Brewing Co.            Boulder      2018
# 334               Upslope Brewing Company            Boulder      2008
# 335                        Ursula Brewery             Aurora      2014
# 336              Ute Pass Brewing Company      Woodland Park      2015
# 337                             Uturn BBQ          Lafayette      2017
# 338                      Vail Brewing Co.               Vail      2015
# 339   Verboten Brewing and Barrel Project           Loveland      2013
# 340             Very Nice Brewing Company          Nederland      2012
# 341      Veteran Brothers Brewing Company          Johnstown      2017
# 342          Vision Quest Brewing Company            Boulder      2015
# 343                Walter Brewing Company             Pueblo      2014
# 344             WeldWerks Brewing Company            Greeley      2015
# 345             West Flanders Brewing Co.            Boulder      2012
# 346      Westbound & Down Brewing Company      Idaho Springs      2015
# 347               WestFax Brewing Company           Lakewood      2016
# 348           Westminster Brewing Company        Westminster      2013
# 349           Whistle Pig Brewing Company   Colorado Springs      2016
# 350                         Wibby Brewing           Longmont      2015
# 351                    Wild Woods Brewery            Boulder      2012
# 352           WildEdge Brewing Collective             Cortez      2017
# 353           Wiley Roots Brewing Company            Greeley      2013
# 354             Wit's End Brewing Company             Denver      2011
# 355                 Wolfe Brewing Company     Pagosa Springs      2015
# 356            Wonderland Brewing Company         Broomfield      2014
# 357            Woods Boss Brewing Company             Denver      2017
# 358               Wynkoop Brewing Company             Denver      1988
# 359          Yampa Valley Brewing Company             Hayden      2015
# 360                          Zulu Brewing           Montrose      2016
# 361                   Zuni Street Brewing             Denver      2017
# 362                          Zwei Brewing       Fort Collins      2014
#
# [363 rows x 3 columns]

# %%
data.to_csv("../brewery_data/breweries_CO.csv", index=False, header=True)

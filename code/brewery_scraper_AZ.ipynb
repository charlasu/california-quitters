# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/arizona/3/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                 Brewery          Location Est. Year
# 0                       12 West Brewing           Gilbert      2016
# 1                  1912 Brewing Company            Tucson      2015
# 2                        8-Bit Aleworks          Avondale      2015
# 3    Arizona Wilderness Brewing Company           Gilbert      2013
# 4                     Bad Water Brewing        Scottsdale      2012
# 5     Barley Brothers Brewery and Grill  Lake Havasu City      1997
# 6              Barnstar Brewing Company      Skull Valley      2013
# 7                    Barrio Brewing Co.            Tucson      2008
# 8                 Beast Brewing Company            Bisbee      2014
# 9                 Beaver Street Brewery         Flagstaff      2002
# 10              Beer Research Institute              Mesa      2014
# 11                     Big E Steakhouse      Grand Canyon      2016
# 12            Black Bridge Brewery (AZ)           Kingman      2014
# 13             Black Horse Brewery (AZ)          Show Low      2015
# 14           Black Mountain Brewing Co.        Cave Creek      2000
# 15                    BlackRock Brewers            Tucson      2017
# 16              Blasted Barley Beer Co.             Tempe      2015
# 17                    Bone Haus Brewing    Fountain Hills      2018
# 18          Borderlands Brewing Company            Tucson      2011
# 19      Brewers Restaurant & Sports Bar              Yuma      2014
# 20                    Button Brew House            Tucson      2017
# 21          Casa Arriba Brewing Company        Scottsdale      2003
# 22             Catalina Brewing Company            Tucson      2016
# 23       College Street Brewhouse & Pub  Lake Havasu City      2012
# 24          Copper Mine Brewing Company            Tucson      2017
# 25                   Coppertop Alehouse          Prescott      2017
# 26                      Corbett Brewery            Tucson      2018
# 27           Cosmic Beer & Distributing         Flagstaff      2012
# 28                             Craft 64        Scottsdale      2016
# 29            Crooked Tooth Brewing Co.            Tucson      2016
# ..                                  ...               ...       ...
# 68               Peoria Artisan Brewery   Litchfield Park      2014
# 69                  Perch Pub & Brewery          Chandler      2014
# 70                  Phoenix Ale Brewery           Phoenix      2011
# 71              Pinetop Brewing Company          Lakeside      2013
# 72             Prescott Brewing Company          Prescott      1994
# 73          Prison Hill Brewing Company              Yuma      2014
# 74             Public Brewhouse Brewery            Tucson      2015
# 75          Pueblo Vida Brewing Company            Tucson      2014
# 76                     Richter Aleworks            Peoria      2016
# 77              Rickety Cricket Brewing           Kingman      2017
# 78                Rock Bottom Arrowhead          Glendale      2004
# 79           Rodeo Cold Brewing Company         New River      2015
# 80              Saddle Mountain Brewing          Goodyear      2014
# 81               SanTan Brewing Company          Chandler      2008
# 82              Scottsdale Beer Company        Scottsdale      2014
# 83        Sentinel Peak Brewing Company            Tucson      2013
# 84          Sleepy Dog Saloon & Brewery             Tempe      2009
# 85              Sonoran Brewing Company           Phoenix      1996
# 86                     State 48 Brewery          Surprise      2016
# 87                       Sun Up Brewery           Phoenix      2001
# 88               Ten Fifty-Five Brewing            Tucson      2012
# 89                   THAT Brewery & Pub              Pine      2012
# 90               The Address Brewing Co            Tucson      2011
# 91                    The Shop Beer Co.             Tempe      2016
# 92               Thunder Canyon Brewery            Tucson      1997
# 93            Tombstone Brewing Company         Tombstone      2016
# 94                 Uncle Bear's Brewery         Ahwatukee      2013
# 95                Verde Brewing Company        Camp Verde      2014
# 96           Wanderlust Brewing Company         Flagstaff      2012
# 97           Wren House Brewing Company           Phoenix      2015
#
# [98 rows x 3 columns]

# %%
data.to_csv("../brewery_data/breweries_AZ.csv", index=False, header=True)

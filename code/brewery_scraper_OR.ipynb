# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/oregon/37/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                                Brewery       Location  \
# 0                         10 Barrel Brewing (AB InBev)           Bend
# 1                                 1188 Brewing Company       John Day
# 2                           13 Virtues Brewing Company       Portland
# 3                           3 Sheets Brewery & Taproom         Albany
# 4                             7 Devils Brewing Company       Coos Bay
# 5                                        Agrarian Ales         Eugene
# 6                                  Alameda Brewing Co.       Portland
# 7                           Alesong Brewing & Blending         Eugene
# 8                                    Aletruism Brewing       Portland
# 9                                     Allegory Brewing    McMinnville
# 10                                     Ambacht Brewing      Hillsboro
# 11                                    Ancestry Brewery       Tualatin
# 12                           Arch Rock Brewing Company     Gold Beach
# 13                   Asher David Brewing & Cellarworks      Silverton
# 14                  Astoria Brewing Co. (Wet Dog Cafe)        Astoria
# 15                                        Awesome Ales       Portland
# 16                                  Back Pedal Brewing       Portland
# 17                            Backside Brewing Company       Roseburg
# 18                                     Baerlic Brewing       Portland
# 19                              Bandon Brewing Company         Bandon
# 20                               Barley Browns Brewpub     Baker City
# 21                  Barley Sprout Restaurant & Brewery        Gresham
# 22                           Base Camp Brewing Company       Portland
# 23                         Beer Valley Brewing Company        Ontario
# 24                           Belgian Underground Beers      Silverton
# 25                             Below Grade Brewing LLC           Bend
# 26                                Bend Brewing Company           Bend
# 27                                 Benedictine Brewery   St. Benedict
# 28                                 Bent Shovel Brewing    Oregon City
# 29                                Bethany Public House       Portland
# ..                                                 ...            ...
# 227                           Three Creeks Brewing Co.        Sisters
# 228                         Three Mugs Brewing Company      Hillsboro
# 229                     Thunder Island Brewing Company  Cascade Locks
# 230                         Tiger Town Brewing Company       Mitchell
# 231                                Tight Lines Brewery      Brookings
# 232                            TrainWreck Brewing, Inc       Portland
# 233                                Tuebor Beer Company       Portland
# 234                          Two Kilts Brewing Company       Sherwood
# 235                            Two Shy Brewing Company       Roseburg
# 236                                    Upright Brewing       Portland
# 237                              Uptown Market Brewing       Portland
# 238                                   Vagabond Brewing          Salem
# 239                           Vanguard Brewing Company    Wilsonville
# 240                                    Vertigo Brewing      Hillsboro
# 241                                  Von Ebert Brewing      Portland
# 242                                  Walkabout Brewing  Central Point
# 243                              Waltz Brewing Company   Forest Grove
# 244                       Way Out West Brewing Company           Bend
# 245                                     Wayfinder Beer       Portland
# 246                             Werner Brewing Company      Tillamook
# 247                                         Whiskyback       Portland
# 248   Widmer Brothers Brewing Company  (Craft Brew ...       Portland
# 249                                  Wild Ride Brewing        Redmond
# 250                         Wild River Brewing Company    Grants Pass
# 251                                  Wolf Tree Brewery      Seal Rock
# 252                  Wolves & People Farmhouse Brewery        Newberg
# 253                             Worthy Brewing Company           Bend
# 254                                      Xicha Brewing          Salem
# 255                                    Yachats Brewing        Yachats
# 256                          Zoiglhaus Brewing Company       Portland
#
#     Est. Year
# 0        2008
# 1        2014
# 2        2013
# 3        2017
# 4        2013
# 5        2012
# 6        2001
# 7        2016
# 8        2018
# 9        2017
# 10       2010
# 11       2016
# 12       2013
# 13       2018
# 14       2003
# 15       2013
# 16       2015
# 17       2016
# 18       2014
# 19       2018
# 20       1998
# 21       2017
# 22       2011
# 23       2006
# 24       2018
# 25       2012
# 26       1996
# 27       2014
# 28       2015
# 29       2014
# ..        ...
# 227      2008
# 228      2014
# 229      2013
# 230      2018
# 231      2013
# 232      2016
# 233      2016
# 234      2011
# 235      2013
# 236      2009
# 237      2014
# 238      2014
# 239      2015
# 240      2008
# 241      2018
# 242      2003
# 243      2014
# 244      2017
# 245      2016
# 246      2017
# 247      2018
# 248      1984
# 249      2014
# 250      2001
# 251      2014
# 252      2014
# 253      2013
# 254      2017
# 255      2015
# 256      2015
#
# [257 rows x 3 columns]

# %%
data.to_csv("../brewery_data/breweries_OR.csv", index=False, header=True)

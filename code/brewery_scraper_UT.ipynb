# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ratebeer.com/breweries/utah/44/213/"

# %%
response = requests.get(url)
page = BeautifulSoup(response.text, "html.parser")

# %%
containers = page.table.find_all("td")

# %%
breweries = []
locations = []

for container in containers:
    
    brewery = container.a
    location = container.find("a", class_="filter")
    
    if brewery == None:
        pass
    else:
        breweries.append(brewery.text)
        
    if location == None:
        pass
    else:
        locations.append(location.text)

# %%
boxes = page.table.find_all("td", style =  ("color:#ccc;text-align:right;"))

dates = []

for box in boxes:
    
    date = box.text
    
    if date == None:
        pass
    else:
        dates.append(date)

# %%
data = pd.DataFrame({
    
    "Brewery": breweries, 
    "Location": locations, 
    "Est. Year": dates
})

data
# Out:
#                                Brewery                       Location  \
# 0                        2 Row Brewing                        Midvale
# 1                A. Fisher Brewing Co.                 Salt Lake City
# 2             Bohemian Brewery & Grill                        Midvale
# 3           Bonneville Brewery Company                         Tooele
# 4                  Desert Edge Brewery                 Salt Lake City
# 5         Epic Brewing Company (UT/CO)                 Salt Lake City
# 6                   Hop N' Keg Brewery                         Vernal
# 7              Hoppers Grill & Brewery                        Midvale
# 8                       Kiitos Brewing                 Salt Lake City
# 9                         Moab Brewery                           Moab
# 10                   Park City Brewery                      Park City
# 11   Pinnacle Brewing Co. (aka Groggs)                         Helper
# 12              Proper Brewing Company                 Salt Lake City
# 13                    Red Rock Brewing                 Salt Lake City
# 14                RoHa Brewing Project                 Salt Lake City
# 15           Roosters Brewing Co. (US)  locations in Ogden and Layton
# 16                  Salt Flats Brewing                 Salt Lake City
# 17            SaltFire Brewing Company                South Salt Lake
# 18      Shades of Pale Brewing Company                 Salt Lake City
# 19         Squatters Craft Beers (FCP)                 Salt Lake City
# 20          Strap Tank Brewing Company                    Springville
# 21            Talisman Brewing Company                          Ogden
# 22              Toasted Barrel Brewery                 Salt Lake City
# 23               Uinta Brewing Company                 Salt Lake City
# 24              Vernal Brewing Company                         Vernal
# 25               Wasatch Brewery (FCP)                      Park City
# 26         Zion Canyon Brewing Company                     Springdale
#
#    Est. Year
# 0       2015
# 1       2017
# 2       2002
# 3       2012
# 4       1995
# 5       2010
# 6       2015
# 7       2003
# 8       2017
# 9       2002
# 10      2015
# 11      2003
# 12      2013
# 13      1994
# 14      2017
# 15      2003
# 16      2018
# 17      2018
# 18      2011
# 19      1989
# 20      2016
# 21      2016
# 22      2018
# 23      1993
# 24      2013
# 25      1986
# 26      2006

# %%
data.to_csv("../brewery_data/breweries_UT.csv", index=False, header=True)
